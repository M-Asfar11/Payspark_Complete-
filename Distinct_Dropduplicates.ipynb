# %%
data = [

        (1, "Asfar", 23),
        (2, "Bilal", 34),
        (3, "Usman", 29),
        (1, "Asfar", 23), # duplicate row
        (2, "Bilal", 34), # duplicate row
        (6, "Asfar", 30) # same name, different age
]

columns = ["id", "name", "age"]

df = spark.createDataFrame(data, columns)
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>age</th></tr></thead><tbody><tr><td>1</td><td>Asfar</td><td>23</td></tr><tr><td>2</td><td>Bilal</td><td>34</td></tr><tr><td>3</td><td>Usman</td><td>29</td></tr><tr><td>1</td><td>Asfar</td><td>23</td></tr><tr><td>2</td><td>Bilal</td><td>34</td></tr><tr><td>6</td><td>Asfar</td><td>30</td></tr></tbody></table></div>

# %%
display(df.distinct())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>age</th></tr></thead><tbody><tr><td>1</td><td>Asfar</td><td>23</td></tr><tr><td>2</td><td>Bilal</td><td>34</td></tr><tr><td>3</td><td>Usman</td><td>29</td></tr><tr><td>6</td><td>Asfar</td><td>30</td></tr></tbody></table></div>

# %%
display(df.dropDuplicates(["id"]))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>age</th></tr></thead><tbody><tr><td>1</td><td>Asfar</td><td>23</td></tr><tr><td>2</td><td>Bilal</td><td>34</td></tr><tr><td>3</td><td>Usman</td><td>29</td></tr><tr><td>6</td><td>Asfar</td><td>30</td></tr></tbody></table></div>
